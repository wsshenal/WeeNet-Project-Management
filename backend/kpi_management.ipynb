# %%
import pprint
import os, json
import pandas as pd 
pd.set_option('display.max_rows', 500)

# %%
roles = [
        'Business Analyst',
        'Backend Engineer',
        'DevOps Engineer',
        'Frontend Engineer',
        'FullStack Engineer',
        'Project Manager',
        'Quality Assurance Engineer', 'Tech Lead'
        ]

# %%
def load_json_files(data_path = 'data/KPI/jsons/'):
    json_arr = {}
    files = os.listdir(data_path)
    for file in files:
        if file.endswith('.json'):
            json_path = os.path.join(data_path, file)
            with open(json_path, 'r') as f:
                data = json.load(f)
                data_updated = {}
                for type, criteria in data.items():
                    data_iter = {}
                    for cri, levels in criteria.items():
                        cri = cri.replace('/', '-')
                        data_iter[cri] = levels
                    data_updated[type] = data_iter

                role = file.split('.')[0]
                json_arr[role] = [data_updated, json_path]
    return json_arr

# %%
json_arr = load_json_files()
pprint.pprint(json_arr)
# Out:
# {'Backend Engineer': [{'education': {"Bachelor's Degree": {'Unrelated': 50,
#                                                            'related': 100},
#                                      "Master's Degree": {'Unrelated': 50,
#                                                          'related': 100}},
#                        'experience': {'Experience of related Domain': {'0 - 5': 20,
#                                                                        '15+': 100,
#                                                                        '6 - 14': 50},
#                                       'Years of experience in Bacend Engineer': {'1-2 years': 20,
#                                                                                  '3-5 years': 50,
#                                                                                  '5+ years': 100}},
#                        'skills': {'API Development and Integration': {'Advanced': 100,
#                                                                       'Intermediate': 50,
#                                                                       'Novice': 20},
#                                   'Database Management (SQL, NoSQL)': {'Advanced': 100,
#                                                                        'Intermediate': 50,
#                                                                        'Novice': 20},
#                                   'Knowledge of Frameworks': {'Advanced': 100,
#                                                               'Intermediate': 50,
#                                                               'Novice': 20},
#                                   'Proficiency in Programming Languages': {'Advanced': 100,
#                                                                            'Intermediate': 50,
#                                                                            'Novice': 20},
#                                   'Understanding of Microservices Architecture': {'Advanced': 100,
#                                                                                   'Intermediate': 50,
#                                                                                   'Novice': 20}}},
#                       'data/KPI/jsons/Backend Engineer.json'],
#  'Business Analyst': [{'education': {"Bachelor's Degree": {'Unrelated': 50,
#                                                            'related': 100},
#                                      "Master's Degree": {'Unrelated': 50,
#                                                          'related': 100}},
#                        'experience': {'Experience of related Domain': {'0 - 5': 20,
#                                                                        '15+': 100,
#                                                                        '6 - 14': 50},
#                                       'Leadership-Team lead experience': {'Leadership': 100,
#                                                                           'Non-Lead': 0},
#                                       'Years of experience in Business Analysis': {'1-2 years': 20,
#                                                                                    '3-5 years': 50,
#                                                                                    '5+ years': 100},
#                                       'etset': {'Unrelated field': '8',
#                                                 'related field': '7'}},
#                        'skills': {'Analytical Skills': {'Advanced': 100,
#                                                         'Intermediate': 50,
#                                                         'Novice': 20},
#                                   'Communication Skills': {'Advanced': 100,
#                                                            'Intermediate': 50,
#                                                            'Novice': 20},
#                                   'Problem Solving Skills': {'Advanced': 100,
#                                                              'Intermediate': 50,
#                                                              'Novice': 20},
#                                   'Technical Proficiency': {'Advanced': 100,
#                                                             'Intermediate': 50,
#                                                             'Novice': 20},
#                                   'dafedaf': {'Advanced': '3',
#                                               'Intermediate': '3',
#                                               'Novice': '33'},
#                                   'lkjdhfdghj': {'Advanced': '8',
#                                                  'Intermediate': '6',
#                                                  'Novice': '4'},
#                                   'test': {'Advanced': '8',
#                                            'Intermediate': '6',
#                                            'Novice': '4'}}},
#                       'data/KPI/jsons/Business Analyst.json'],
#  'DevOps Engineer': [{'education': {"Bachelor's Degree": {'Unrelated': 50,
#                                                           'related': 100},
#                                     "Master's Degree": {'Unrelated': 50,
#                                                         'related': 100}},
#                       'experience': {'Experience of related Domain': {'0 - 5': 20,
#                                                                       '15+': 100,
#                                                                       '6 - 14': 50},
#                                      'Leadership-Team lead experience': {'Leadership': 100,
#                                                                          'Non-Lead': 0},
#                                      'Years of experience in DevOps Engineer': {'1-2 years': 20,
#                                                                                 '3-5 years': 50,
#                                                                                 '5+ years': 100}},
#                       'skills': {'Cloud Platforms ( AWS, Azure, GCP)': {'Advanced': 100,
#                                                                         'Intermediate': 50,
#                                                                         'Novice': 20},
#                                  'Configuration Management Tools': {'Advanced': 100,
#                                                                     'Intermediate': 50,
#                                                                     'Novice': 20},
#                                  'Continuous Integration-Continuous Deployment': {'Advanced': 100,
#                                                                                   'Intermediate': 50,
#                                                                                   'Novice': 20},
#                                  'Monitoring and Logging Tools': {'Advanced': 100,
#                                                                   'Intermediate': 50,
#                                                                   'Novice': 20},
#                                  'Scripting and Automation (Python, Bash)': {'Advanced': 100,
#                                                                              'Intermediate': 50,
#                                                                              'Novice': 20}}},
#                      'data/KPI/jsons/DevOps Engineer.json'],
#  'Frontend Engineer': [{'education': {"Bachelor's Degree": {'Unrelated': 50,
#                                                             'related': 100},
#                                       "Master's Degree": {'Unrelated': 50,
#                                                           'related': 100}},
#                         'experience': {'Experience of related Domain': {'0 - 5': 20,
#                                                                         '15+': 100,
#                                                                         '6 - 14': 50},
#                                        'Years of experience in FrontEnd engineer': {'1-2 years': 20,
#                                                                                     '3-5 years': 50,
#                                                                                     '5+ years': 100}},
#                         'skills': {'Knowledge of Frontend Frameworks-Libraries': {'Advanced': 100,
#                                                                                   'Intermediate': 50,
#                                                                                   'Novice': 20},
#                                    'Proficiency in HTML-CSS': {'Advanced': 100,
#                                                                'Intermediate': 50,
#                                                                'Novice': 20},
#                                    'Proficiency in JavaScript-TypeScript': {'Advanced': 100,
#                                                                             'Intermediate': 50,
#                                                                             'Novice': 20},
#                                    'Responsive Design and Cross-Browser Compatibility': {'Advanced': 100,
#                                                                                          'Intermediate': 50,
#                                                                                          'Novice': 20},
#                                    'UI-UX Design Principles': {'Advanced': 100,
#                                                                'Intermediate': 50,
#                                                                'Novice': 20}}},
#                        'data/KPI/jsons/Frontend Engineer.json'],
#  'FullStack Engineer': [{'education': {"Bachelor's Degree": {'Unrelated': 5,
#                                                              'related': 10},
#                                        "Master's Degree": {'Unrelated': 50,
#                                                            'related': 100}},
#                          'experience': {'Experience of related Domain': {'0 - 5': 20,
#                                                                          '15+': 100,
#                                                                          '6 - 14': 50},
#                                         'Years of experience in Fullstack engineer': {'1-2 years': 20,
#                                                                                       '3-5 years': 50,
#                                                                                       '5+ years': 100}},
#                          'skills': {'API Development and Integration': {'Advanced': 100,
#                                                                         'Intermediate': 50,
#                                                                         'Novice': 20},
#                                     'Database Management (SQL, NoSQL)': {'Advanced': 100,
#                                                                          'Intermediate': 50,
#                                                                          'Novice': 20},
#                                     'Knowledge of Backend Frameworks': {'Advanced': 100,
#                                                                         'Intermediate': 50,
#                                                                         'Novice': 20},
#                                     'Knowledge of Frontend Frameworks': {'Advanced': 100,
#                                                                          'Intermediate': 50,
#                                                                          'Novice': 20},
#                                     'Proficiency in Backend Technologies': {'Advanced': 100,
#                                                                             'Intermediate': 50,
#                                                                             'Novice': 20},
#                                     'Proficiency in Frontend Technologies': {'Advanced': 100,
#                                                                              'Intermediate': 50,
#                                                                              'Novice': 20}}},
#                         'data/KPI/jsons/FullStack Engineer.json'],
#  'Project Manager': [{'education': {"Bachelor's Degree": {'Unrelated': 50,
#                                                           'related': 100},
#                                     "Master's Degree": {'Unrelated': 50,
#                                                         'related': 100}},
#                       'experience': {'Experience of related Domain': {'0 - 5': 20,
#                                                                       '15+': 100,
#                                                                       '6 - 14': 50},
#                                      'Years of experience in Fullstack engineer': {'1-2 years': 20,
#                                                                                    '3-5 years': 50,
#                                                                                    '5+ years': 100}},
#                       'skills': {'Budgeting and Cost Control': {'Advanced': 100,
#                                                                 'Intermediate': 50,
#                                                                 'Novice': 20},
#                                  'Communication Skills': {'Advanced': 100,
#                                                           'Intermediate': 50,
#                                                           'Novice': 20},
#                                  'Knowledge of Project Management Methodologies': {'Advanced': 100,
#                                                                                    'Intermediate': 50,
#                                                                                    'Novice': 20},
#                                  'Leadership and Team Management': {'Advanced': 100,
#                                                                     'Intermediate': 50,
#                                                                     'Novice': 20},
#                                  'Risk Management': {'Advanced': 100,
#                                                      'Intermediate': 50,
#                                                      'Novice': 20},
#                                  'planning & scheduling': {'Advanced': 100,
#                                                            'Intermediate': 50,
#                                                            'Novice': 20}}},
#                      'data/KPI/jsons/Project Manager.json'],
#  'Quality Assurance Engineer': [{'education': {"Bachelor's Degree": {'Unrelated': 50,
#                                                                      'related': 100},
#                                                "Master's Degree": {'Unrelated': 50,
#                                                                    'related': 100}},
#                                  'experience': {'Experience of related Domain': {'0 - 5': 20,
#                                                                                  '15+': 100,
#                                                                                  '6 - 14': 50},
#                                                 'Leadership-Team lead experience': {'Leadership': 100,
#                                                                                     'Non-Lead': 0},
#                                                 'Years of experience in QA': {'1-2 years': 20,
#                                                                               '3-5 years': 50,
#                                                                               '5+ years': 100}},
#                                  'skills': {'Bug tracking and reporting': {'Advanced': 100,
#                                                                            'Intermediate': 50,
#                                                                            'Novice': 20},
#                                             'Excellent communication': {'Advanced': 100,
#                                                                         'Intermediate': 50,
#                                                                         'Novice': 20},
#                                             'Knowledge of testing methodologies': {'Advanced': 100,
#                                                                                    'Intermediate': 50,
#                                                                                    'Novice': 20},
#                                             'Test Automation': {'Advanced': 100,
#                                                                 'Intermediate': 50,
#                                                                 'Novice': 20}}},
#                                 'data/KPI/jsons/Quality Assurance '
#                                 'Engineer.json'],
#  'Tech Lead': [{'education': {"Bachelor's Degree": {'Unrelated': 50,
#                                                     'related': 100},
#                               "Master's Degree": {'Unrelated': 50,
#                                                   'related': 100}},
#                 'experience': {'Experience of related Domain': {'0 - 5': 20,
#                                                                 '15+': 100,
#                                                                 '6 - 14': 50},
#                                'Years of experience in Tech Lead': {'1-2 years': 20,
#                                                                     '3-5 years': 50,
#                                                                     '5+ years': 100}},
#                 'skills': {'Communication and Collaboration': {'Advanced': 100,
#                                                                'Intermediate': 50,
#                                                                'Novice': 20},
#                            'Leadership and Team Management': {'Advanced': 100,
#                                                               'Intermediate': 50,
#                                                               'Novice': 20},
#                            'Problem-Solving and Decision-Making': {'Advanced': 100,
#                                                                    'Intermediate': 50,
#                                                                    'Novice': 20},
#                            'Project Management Skills': {'Advanced': 100,
#                                                          'Intermediate': 50,
#                                                          'Novice': 20},
#                            'Technical Expertise': {'Advanced': 100,
#                                                    'Intermediate': 50,
#                                                    'Novice': 20}}},
#                'data/KPI/jsons/Tech Lead.json']}

# %%
def load_csv_files(data_path = 'data/KPI/weights/'):
    df_arr = {}
    files = os.listdir(data_path)
    for file in files:
        if file.endswith('.xlsx'):
            excel_path = os.path.join(data_path, file)
            with open(excel_path, 'r') as f:
                df = pd.read_excel(excel_path)
                df = df[['Criteria', 'Weight']]
                role = file.split('.')[0]
                df_arr[role] = df
    return df_arr

# %%
df_arr = load_csv_files()
df_arr
# Out:
# {'Backend Engineer':                                       Criteria  Weight
#  0         Proficiency in Programming Languages    0.15
#  1             Database Management (SQL, NoSQL)    0.15
#  2              API Development and Integration    0.10
#  3                      Knowledge of Frameworks    0.10
#  4  Understanding of Microservices Architecture    0.05
#  5             Years of experience in Tech Lead    0.15
#  6                 Experience of related Domain    0.10
#  7                            Bachelor's Degree    0.10
#  8                              Master's Degree    0.10,
#  'Business Analyst':                                    Criteria  Weight
#  0                         Analytical Skills    0.20
#  1                     Technical Proficiency    0.10
#  2                      Communication Skills    0.15
#  3                    Problem Solving Skills    0.05
#  4  Years of experience in Business Analysis    0.15
#  5              Experience of related Domain    0.10
#  6           Leadership/Team lead experience    0.05
#  7                           Master's Degree    0.10
#  8                         Bachelor's Degree    0.10,
#  'DevOps Engineer':                                        Criteria  Weight
#  0       Scripting and Automation (Python, Bash)    0.20
#  1  Continuous Integration/Continuous Deployment    0.05
#  2            Cloud Platforms ( AWS, Azure, GCP)    0.10
#  3                Configuration Management Tools    0.10
#  4                  Monitoring and Logging Tools    0.05
#  5        Years of experience in DevOps Engineer    0.15
#  6                  Experience of related Domain    0.10
#  7               Leadership/Team lead experience    0.05
#  8                             Bachelor's Degree    0.10
#  9                               Master's Degree    0.10,
#  'Frontend Engineer':                                             Criteria  Weight
#  0                            Proficiency in HTML/CSS    0.15
#  1               Proficiency in JavaScript/TypeScript    0.10
#  2         Knowledge of Frontend Frameworks/Libraries    0.15
#  3                            UI/UX Design Principles    0.10
#  4  Responsive Design and Cross-Browser Compatibility    0.05
#  5           Years of experience in FrontEnd engineer    0.15
#  6                       Experience of related Domain    0.10
#  7                                  Bachelor's Degree    0.10
#  8                                    Master's Degree    0.10,
#  'FullStack Engineer':                                     Criteria  Weight
#  0       Proficiency in Frontend Technologies    0.10
#  1       Proficiency in Backend Technologies     0.10
#  2          Knowledge of  Frontend Frameworks    0.10
#  3            Knowledge of Backend Frameworks    0.10
#  4           Database Management (SQL, NoSQL)    0.05
#  5            API Development and Integration    0.15
#  6  Years of experience in Fullstack engineer    0.10
#  7               Experience of related Domain    0.10
#  8                          Bachelor's Degree    0.10
#  9                            Master's Degree    0.10,
#  'Project Manager':                                        Criteria  Weight
#  0                         planning & scheduling    0.10
#  1                Leadership and Team Management    0.15
#  2                          Communication Skills    0.10
#  3                               Risk Management    0.05
#  4                    Budgeting and Cost Control    0.05
#  5  Knowledge of Project Management Methodologie    0.15
#  6     Years of experience in Fullstack engineer    0.10
#  7                  Experience of related Domain    0.10
#  8                             Bachelor's Degree    0.10
#  9                               Master's Degree    0.10,
#  'Quality Assurance Engineer':                              Criteria  Weight
#  0            Excellent communication     0.05
#  1                     Test Automation    0.20
#  2  Knowledge of testing methodologies    0.15
#  3          Bug tracking and reporting    0.10
#  4           Years of experience in QA    0.15
#  5        Experience of related Domain    0.10
#  6     Leadership/Team lead experience    0.05
#  7                   Bachelor's Degree    0.10
#  8                     Master's Degree    0.10,
#  'Tech Lead':                               Criteria  Weight
#  0                  Technical Expertise    0.15
#  1       Leadership and Team Management    0.15
#  2            Project Management Skills    0.05
#  3  Problem-Solving and Decision-Making    0.10
#  4      Communication and Collaboration    0.10
#  5     Years of experience in Tech Lead    0.15
#  6         Experience of related Domain    0.10
#  7                    Bachelor's Degree    0.10
#  8                      Master's Degree    0.10}

# %%
crud_json = {
        "type" : "skills",
        "criteria" : "Analytical Skills KKK",
        "level" : {
                "Novice":1,
                "Intermediate":3,
                "Advanced":5
                },
        "weight" : 0.20
        }

# %%
def crud_kpi_criterias(
                        crud_json, role, 
                        operation = 'add' # ['add', 'delete', 'update']
                        ):
    try:
        json_arr = load_json_files()
        df_arr = load_csv_files()
        if operation == 'add':
            df_role = df_arr[role]
            if crud_json['criteria'] in df_role['Criteria'].values:
                return "Criteria Already Exists !!!"
            
            df_weights = pd.DataFrame({
                                    'Criteria' : [crud_json['criteria']],
                                    'Weight' : [crud_json['weight']]
                                    })
            df_role = pd.concat([df_role, df_weights], axis = 0)
            
            json_role, json_role_path = json_arr[role]
            json_role[crud_json["type"]][crud_json["criteria"]] = crud_json["level"]


        elif operation == 'delete':
            df_role = df_arr[role]
            if crud_json['criteria'] not in df_role['Criteria'].values:
                return "Criteria Does Not Exists !!!"
            
            df_role = df_role[df_role['Criteria'] != crud_json['criteria']]
            
            json_role, json_role_path = json_arr[role]
            del json_role[crud_json["type"]][crud_json["criteria"]]
            

        elif operation == 'update':
            df_role = df_arr[role]
            if crud_json['criteria'] not in df_role['Criteria'].values:
                return "Criteria Does Not Exists !!!"
            
            df_role.loc[df_role['Criteria'] == crud_json['criteria'], 'Weight'] = crud_json['weight']
            
            json_role, json_role_path = json_arr[role]
            json_role[crud_json["type"]][crud_json["criteria"]] = crud_json["level"]
            

        with open(json_role_path, 'w') as f:
            json.dump(json_role, f)

        # recalculate the weights
        df_role['Weight'] = df_role['Weight'] / df_role['Weight'].sum()
        df_role.to_excel(
                        f'data/KPI/weights/{role}.xlsx', 
                        index = False
                        )
        return "CRUD Operation Successful !!!"

    except Exception as e:
        return str(e)

# %%
def apply_kpi_level(row, json_role_updated=None):
    """Calculate KPI value for a single criteria"""
    weight = row['Weight']
    criteria = row['Criteria'].replace('\\/', '-').replace('\\', '').replace('/', '-')
    level = row['Level']
    
    # Skip fields that are not KPI criteria (personal information)
    skip_fields = ['Name', 'Phone Number', 'Home Town', 'Age']
    if criteria in skip_fields:
        return 0
    
    # Check if criteria exists in json_role_updated
    if criteria not in json_role_updated:
        print(f"Warning: Criteria '{criteria}' not found in KPI definitions")
        return 0
    
    # Check if level exists for this criteria
    if level not in json_role_updated[criteria]:
        print(f"Warning: Level '{level}' not found for criteria '{criteria}'")
        return 0
    
    value = json_role_updated[criteria][level]
    return value * weight


def calculate_kpi_value(role, criteria_json):
    """Calculate total KPI value for an employee"""
    df_arr = load_csv_files()
    json_arr = load_json_files()

    df_role = df_arr[role]
    df_role['Criteria'] = df_role['Criteria'].str.replace('\\/', '-').str.replace('\\', '').str.replace('/', '-')
    json_role = json_arr[role][0]

    json_role_updated = {}
    for _, value in json_role.items():
        for k, v in value.items():
            json_role_updated[k] = v

    criteria_df = pd.DataFrame(criteria_json, index=[0]).T
    criteria_df = criteria_df.reset_index()
    criteria_df.columns = ['Criteria', 'Level']
    criteria_df['Criteria'] = criteria_df['Criteria'].str.strip()
    criteria_df['Level'] = criteria_df['Level'].str.strip()
    
    # Filter out personal information fields before merging
    personal_fields = ['Name', 'Phone Number', 'Home Town', 'Age']
    criteria_df = criteria_df[~criteria_df['Criteria'].isin(personal_fields)]
    
    criteria_df = criteria_df.merge(df_role, on='Criteria', how='left')
    criteria_df['Weight'] = criteria_df['Weight'].fillna(0)
    criteria_df['KPI'] = criteria_df.apply(
        apply_kpi_level, axis=1, json_role_updated=json_role_updated
    )
    kpi_value = criteria_df['KPI'].sum()
    return kpi_value


def calculate_kpi_sheet(role, domain, employee_file_path='data/KPI/employees.xlsx'):
    """Calculate KPI values for all employees of a specific role and domain"""
    df_kpi = {
        'EmpID': [],
        'Domain': [],
        'Role': [],
        'KPI': []
    }

    df_role_values = pd.read_excel(employee_file_path, sheet_name=role)
    df_role_values = df_role_values[df_role_values['Domain'] == domain]
    df_role_values.reset_index(drop=True, inplace=True)

    for i in range(df_role_values.shape[0]):
        criteria_json = eval(df_role_values.loc[i, :].to_json())
        criteria_json = {
            k.replace('\\/', '-').replace('\\', '').replace('/', '-'): v 
            for k, v in criteria_json.items()
        }
        
        emp_id = criteria_json['EMP ID']
        domain = criteria_json['Domain']
        
        # Remove personal and non-KPI fields
        fields_to_remove = ['EMP ID', 'Domain', 'Name', 'Phone Number', 'Home Town', 'Age']
        for field in fields_to_remove:
            if field in criteria_json:
                del criteria_json[field]
        
        kpi_value = calculate_kpi_value(role, criteria_json)

        df_kpi['KPI'].append(kpi_value)
        df_kpi['Domain'].append(domain)
        df_kpi['EmpID'].append(emp_id)
        df_kpi['Role'].append(role)

    df_kpi = pd.DataFrame(df_kpi)
    df_kpi = df_kpi[['EmpID', 'KPI']]
    return df_kpi

# %%
criteria_json = {
                "Analytical Skills":"Advanced ",
                "Technical Proficiency":"Advanced ",
                "Communication Skills":"Advanced ",
                "Problem Solving Skills":"Advanced ",
                "Years of experience in Business Analysis":"5+ years",
                "Experience of related Domain":"15+ ",
                "Leadership-Team lead experience":"Leadership",
                "Bachelor's Degree":"related",
                "Master's Degree":"related"
                }
calculate_kpi_value('Business Analyst', criteria_json)
# Out:
# np.float64(100.0)

# %%
calculate_kpi_sheet('Business Analyst', 'Finance')
# Out:
#    EmpID    KPI
# 0    BA1  100.0
# 1    BA2   62.5
# 2    BA3   25.0
# 3    BA4   78.5
# 4    BA5   42.5
# 5    BA6   75.0
# 6    BA7   54.0
# 7    BA8   60.5
# 8    BA9   65.0
# 9   BA10   63.5
# 10  BA11  100.0
# 11  BA12  100.0
# 12  BA13   45.0
# 13  BA14  100.0
# 14  BA15   43.5
